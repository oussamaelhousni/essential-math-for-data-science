# %%
# Series
import pandas as pd

serie = pd.Series([1,2,3],index=["first","second","last"])

print(serie.loc["first"])
# Out:
# 1

# %%
# dataframe
df = pd.DataFrame({
    "math":[10,20,15],
    "arabic":[10,20,15],
    "bio":[10,20,15]
})

df_2 = pd.DataFrame([
    [10,10,10],
    [20,20,20],
    [15,15,15]
],columns=["math","arabic","bio"])

df
# Out:
#    math  arabic  bio
# 0    10      10   10
# 1    20      20   20
# 2    15      15   15

# %%
# first 5 rows
df.head()
# Out:
#    math  arabic  bio
# 0    10      10   10
# 1    20      20   20
# 2    15      15   15

# %%
# last 5 rows
df.tail()
# Out:
#    math  arabic  bio
# 0    10      10   10
# 1    20      20   20
# 2    15      15   15

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   math    3 non-null      int64
#  1   arabic  3 non-null      int64
#  2   bio     3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0 bytes

# %%
# get a single column
df["math"]
# Out:
# 0    10
# 1    20
# 2    15
# Name: math, dtype: int64

# %%
# get two columns dataframe
df[["math","bio"]]
# Out:
#    math  bio
# 0    10   10
# 1    20   20
# 2    15   15

# %%
# row access
df.loc[0,["math","bio"]] # access by label
# Out:
# math    10
# bio     10
# Name: 0, dtype: int64

# %%
# row access by index
df.iloc[0:2,0:2]
# Out:
#    math  arabic
# 0    10      10
# 1    20      20

# %%
# boolean indexing
df[df["math"]<=15]
# Out:
#    math  arabic  bio
# 0    10      10   10
# 2    15      15   15

# %%
df[df['math'].isin([15,10])]
# Out:
#    math  arabic  bio
# 0    10      10   10
# 2    15      15   15

# %%
df['total'] = 5000

# %%
# drop a column
df.drop("total",axis=1)
# Out:
#    math  arabic  bio
# 0    10      10   10
# 1    20      20   20
# 2    15      15   15

# %%
df = df.rename(columns={'math': 'mathematics'})

# %%
df
# Out:
#    mathematics  arabic  bio  total
# 0           10      10   10   5000
# 1           20      20   20   5000
# 2           15      15   15   5000

# %%
df.mean()
# Out:
# mathematics      15.0
# arabic           15.0
# bio              15.0
# total          5000.0
# dtype: float64

# %%
df['rank'] = df['bio'].rank()
df
# Out:
#    mathematics  arabic  ...  total  rank
# 0           10      10  ...   5000   1.0
# 1           20      20  ...   5000   3.0
# 2           15      15  ...   5000   2.0
#
# [3 rows x 5 columns]

# %%
df.iloc[1,2] = 10 
df.groupby("bio")["arabic"].mean()
# Out:
# bio
# 10    15.0
# 15    15.0
# Name: arabic, dtype: float64

# %%
df.groupby('bio').agg({
 'mathematics': ['mean', 'sum', 'count'],
 'arabic': 'mean'
})
# Out:
#     mathematics           arabic
#            mean sum count   mean
# bio
# 10         15.0  30     2   15.0
# 15         15.0  15     1   15.0
